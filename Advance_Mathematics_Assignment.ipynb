# %% [markdown]
# <a href="https://colab.research.google.com/github/Kumarkashish511/Advance_Mathematics_Assignment/blob/main/Advance_Mathematics_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

roll_no = 102317239

data = pd.read_csv("Data_1.csv", encoding="latin1")

no2_values = data["no2"].values
no2_values = no2_values[~np.isnan(no2_values)]

a_val = 0.05 * (roll_no % 7)
b_val = 0.3 * ((roll_no % 5) + 1)

z_data = no2_values + a_val * np.sin(b_val * no2_values)

mean_z = np.mean(z_data)
var_z = np.var(z_data)

lambda_hat = 1 / (2 * var_z)
c_hat = 1 / np.sqrt(2 * np.pi * var_z)

print("Estimated Parameters:")
print(f"lambda = {lambda_hat:.6f}")
print(f"mu     = {mean_z:.6f}")
print(f"c      = {c_hat:.6f}")


plt.figure(figsize=(8, 5))
plt.hist(z_data, bins=50, density=True, alpha=0.6, label="Observed z values")

z_range = np.linspace(np.min(z_data), np.max(z_data), 100)
pdf_estimate = c_hat * np.exp(-lambda_hat * (z_range - mean_z) ** 2)

plt.plot(z_range, pdf_estimate, 'r-', linewidth=2, label="Estimated PDF")
plt.xlabel("z")
plt
# Out:
# /tmp/ipython-input-1119859812.py:7: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Data_1.csv", encoding="latin1")
# Estimated Parameters:
# lambda = 0.001461
# mu     = 25.814687
# c      = 0.021567
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>
